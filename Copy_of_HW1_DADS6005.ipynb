# %% [markdown]
# <a href="https://colab.research.google.com/github/RatanakamonS/DADS5001-PART1/blob/main/Copy_of_HW1_DADS6005.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pytchat
# !pip install emoji --upgrade

# %%
import pytchat
import emoji
import pandas as pd

def clean_message(msg):
    return msg.replace("::", ": :")

chat_data = []

chat = pytchat.create(video_id="8IlNjufJb3Y")
while chat.is_alive():
    for c in chat.get().sync_items():
      message = clean_message(emoji.emojize(c.message, language='alias'))   #เพิ่ม language='alias'
      print(f"{c.datetime} [{c.author.name}]- {message}") #c. ออก จาก Messege

      chat_data.append({
          'datetime': c.datetime,
          'author': c.author.name,
          'message': message #c. ออก
          })

df = pd.DataFrame(chat_data)
df.to_csv('Taengmo_live_chat.csv', index=False, encoding='utf-8-sig')

from google.colab import files
files.download("Taengmo_live_chat.csv")

print("\nบันทึกไฟล์เรียบร้อยแล้ว: youtube_chat.csv")
# Out:
# Streaming output truncated to the last 5000 lines.
# 2025-01-23 02:56:37 [Piyaphat Bunjansri]- อย่าหนีนะครับ
# 2025-01-23 02:56:44 [Ben GY]- นอนหลับทั้งป่าวเหอะ สวรรคในอกนรกในใจ
# 2025-01-23 02:56:45 [Devil]- เธอ..ไม่ใช่เพื่อนแตงโม
# 2025-01-23 02:56:46 [กมล คนรักพัทยา]- รอดูความเป็นจริง
# 2025-01-23 02:56:49 [darkgod]- Ms Ksiriwan รักแตงโม หรือ เกาะกระแส แตงโม พวกมุงต้องแยกให้ออกนะ มันมีเส้นบางๆ สติค่ะ
# 2025-01-23 02:56:49 [นาย ประภาส สุภนิกร]- ตอเหล่ใจผั่นแปรเป็นอื่น
# 2025-01-23 02:56:51 [Tos]- ยังตลกได้อยู่
# 2025-01-23 02:56:51 [Jeneralz]- แม๊กคราวหน้าฝากถามหน่อย อาทิตย์นึงมันนอนกี่วัน:face-blue-smiling: :face-blue-smiling:
# 2025-01-23 02:56:53 [Msound20th]- omg
# 2025-01-23 02:56:55 [กล้วยไข่]- ปากๆ
# 2025-01-23 02:56:56 [ปานุวัฒน์ คชพรม]- แซะคนอื่นอย่างกะตัวเองดีนัก
# 2025-01-23 02:56:56 [นู๋แป้งฝุ่นน่ะค่ะ]- แช่บหมือนเดิม
# 2025-01-23 02:56:58 [อรัญญา สังข์ทอง]- ช
# 2025-01-23 02:56:59 [ภูกาญจน์ คังฆะ]- นายแซน…คุกๆๆน่าตะรออยู่นะ
# ...
