# %% [markdown]
# <a href="https://colab.research.google.com/github/RatanakamonS/DADS5001-PART1/blob/main/HW3_6620422002_Ratanakamon_Somklang.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PRACTICE
#
# 1. (3 point) Display pokemons by pokedex number, English name, and the number of its possible moves. Sort pokemons by the number of possible moves (from largest to smallest). Resultant dataframe expected by this question is shown in `pandas4_question1_answer.csv`.
#   - The number of possible moves regarding a pokemon is considered from their type1 and type2.
#   - Be careful not to over count the possible moves when type1 and type2 are the same.
#   - Be careful not to count the same move more than once.

# %% [markdown]
# แสดงข้อมูลโปเกมอนโดยเรียงตาม `pokedex number`, `English name` และ `the number of its possible moves` จัดเรียงโปเกมอนตาม `the number of its possible moves` (จากมากไปน้อย) DataFrame ที่ได้ควรตรงกับที่แสดงใน `pandas4_question1_answer.csv`.
#
#
# ---
#
#
# -  `the number of its possible moves` ของโปเกมอนพิจารณาจากประเภทที่ 1 (type1) และประเภทที่ 2 (type2) ของมัน
# - ระวังอย่านับท่าโจมตีซ้ำเมื่อประเภทที่ 1 และประเภทที่ 2 เป็นประเภทเดียวกัน
# - ระวังอย่านับท่าโจมตีเดียวกันมากกว่าหนึ่งครั้ง

# %%
import pandas as pd

# %%
# อ่านข้อมูลจาก CSV files
pokemon_df = pd.read_csv('https://raw.githubusercontent.com/RatanakamonS/DADS5001-PART1/main/w4-pokemon%20(1).csv')
moves_df = pd.read_csv('https://raw.githubusercontent.com/RatanakamonS/DADS5001-PART1/refs/heads/main/w4-pokemon-move-data.csv')

# %%
# สร้าง DataFrame ย่อยสำหรับข้อมูลที่ต้องการ
df1_pokemon = pokemon_df.loc[:, ['pokedex_number', 'name', 'type1', 'type2']]
df2_moves = moves_df.loc[:, ['Type', 'Name']]

# %%
# แปลงประเภทให้เป็นตัวพิมพ์เล็กทั้งหมด
df2_moves['Type'] = df2_moves['Type'].str.lower()
df1_pokemon['type1'] = df1_pokemon['type1'].str.lower()
df1_pokemon['type2'] = df1_pokemon['type2'].str.lower()

# %%
# สร้าง DataFrame โดย merge df1_pokemon และ df2_moves
df_inner1 = pd.merge(df1_pokemon, df2_moves, left_on='type1', right_on='Type', how='left')
df_inner2 = pd.merge(df1_pokemon, df2_moves, left_on='type2', right_on='Type', how='left')

# รวม df_inner1 และ df_inner2
df_combined = pd.concat([df_inner1, df_inner2], ignore_index=True)

# ลบแถวที่ซ้ำกัน
df_combined = df_combined.drop_duplicates()

# %%
# นับจำนวนท่าโจมตีที่เป็นไปได้สำหรับแต่ละโปเกมอน
move_counts = df_combined.groupby('pokedex_number')['Name'].nunique()

# เพิ่มคอลัมน์ possible_moves_count ใน df1_pokemon
df1_pokemon['possible_moves_count'] = df1_pokemon['pokedex_number'].map(move_counts)

# เรียงลำดับข้อมูลตามเงื่อนไขที่กำหนด
result_df = df1_pokemon.sort_values(['possible_moves_count', 'pokedex_number'], ascending=[False, True])

# เลือกคอลัมน์ที่ต้องการแสดงผล
result_df = result_df[['pokedex_number', 'name', 'possible_moves_count']].reset_index(drop=True)
result_df
# Out:
#      pokedex_number       name  possible_moves_count
# 0               203  Girafarig                   243
# 1               648   Meloetta                   243
# 2               765   Oranguru                   243
# 3               759    Stufful                   223
# 4               760     Bewear                   223
# ..              ...        ...                   ...
# 796             621  Druddigon                    18
# 797             704      Goomy                    18
# 798             705    Sliggoo                    18
# 799             706     Goodra                    18
# 800             782   Jangmo-o                    18
#
# [801 rows x 3 columns]
